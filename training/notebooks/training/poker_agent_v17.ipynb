# %% [markdown]
# # Poker Agent V17: Self-Play Training
#
# Key features:
# - 6-player table (agent + 5 opponents)
# - **Self-play mode**: Agent plays against past versions of itself
# - Mixed training: 80% self-play + 20% scripted opponents
# - Stronger penalties: All-in loss -10BB, Bust -50BB
# - 30 hands per session (longer sessions)
# - Dynamic epsilon decay based on training duration

# %%
import sys
import os
# Add project root and src directories to path
project_root = os.path.dirname(os.path.dirname(os.path.abspath(__file__))) if '__file__' in dir() else os.getcwd()
while 'src' not in os.listdir(project_root) and project_root != '/':
    project_root = os.path.dirname(project_root)
sys.path.insert(0, project_root)
sys.path.insert(0, os.path.join(project_root, 'src', 'models'))
sys.path.insert(0, os.path.join(project_root, 'src', 'workers'))

import os
import time
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp

from poker_worker_v17 import run_session_v17, POSITION_NAMES
from poker_model_v17 import (
    DuelingPokerNet, PrioritizedReplayBuffer, NUM_ACTIONS_V17, OpponentPool,
    compute_hand_strength_category, compute_v17_session_reward
)

# %%
# Configuration
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Training config
NUM_WORKERS = 6
SESSIONS_PER_BATCH = 12
NUM_ACTIONS = NUM_ACTIONS_V17
STATE_DIM = 520
EQUITY_ITERATIONS = 20
HANDS_PER_SESSION = 30  # V17: longer sessions

# Self-play config
SELF_PLAY_RATIO = 0.8  # 80% self-play, 20% scripted
OPPONENT_POOL_SIZE = 15  # Max snapshots to keep
SNAPSHOT_INTERVAL = 500  # Save snapshot every N sessions

# Logging intervals (as percentage of total sessions)
LOG_PERCENT = 2.0
CHECKPOINT_PERCENT = 10.0
# Out:
# Using device: cuda

# %%
class DuelingAgent:
    """Dueling DQN agent with PER for 6-max poker with self-play."""
    
    def __init__(self, state_dim: int = 520, hidden_dim: int = 512):
        self.device = device
        self.policy_net = DuelingPokerNet(state_dim, hidden_dim).to(device)
        self.target_net = DuelingPokerNet(state_dim, hidden_dim).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=3e-4)
        self.buffer = PrioritizedReplayBuffer(capacity=300000)
        
        # Opponent pool for self-play
        self.opponent_pool = []
        
        self.gamma = 0.99
        self.batch_size = 64
        self.epsilon = 1.0
        self.epsilon_min = 0.05
        self.epsilon_decay = 0.9995  # Will be recalculated dynamically
    
    def get_model_state_dict_cpu(self):
        return {k: v.cpu() for k, v in self.policy_net.state_dict().items()}
    
    def save_snapshot_to_pool(self):
        """Save current model to opponent pool."""
        snapshot = self.get_model_state_dict_cpu()
        self.opponent_pool.append(snapshot)
        # Keep pool size bounded
        if len(self.opponent_pool) > OPPONENT_POOL_SIZE:
            self.opponent_pool.pop(0)  # FIFO
    
    def get_opponent_pool_state_dicts(self):
        """Get list of opponent state dicts for workers."""
        return self.opponent_pool.copy()
    
    def add_transitions(self, transitions):
        self.buffer.push_batch(transitions)
    
    def train_step(self) -> float:
        if len(self.buffer) < self.batch_size:
            return 0.0
        
        samples, indices, weights = self.buffer.sample(self.batch_size)
        if not samples:
            return 0.0
        
        states = torch.FloatTensor([s[0] for s in samples]).to(self.device)
        actions = torch.LongTensor([s[1] for s in samples]).to(self.device)
        rewards = torch.FloatTensor([s[2] for s in samples]).to(self.device)
        next_states = torch.FloatTensor([s[3] for s in samples]).to(self.device)
        dones = torch.FloatTensor([s[4] for s in samples]).to(self.device)
        weights = torch.FloatTensor(weights).to(self.device)
        
        # Current Q values
        q_values = self.policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        
        # Double DQN target
        with torch.no_grad():
            next_actions = self.policy_net(next_states).argmax(1)
            next_q = self.target_net(next_states).gather(1, next_actions.unsqueeze(1)).squeeze(1)
            targets = rewards + self.gamma * next_q * (1 - dones)
        
        # Weighted loss
        td_errors = q_values - targets
        loss = (weights * td_errors.pow(2)).mean()
        
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1.0)
        self.optimizer.step()
        
        # Update priorities
        self.buffer.update_priorities(indices, td_errors.detach().cpu().numpy())
        
        return loss.item()
    
    def update_target(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())
    
    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

# %%
def train_v17_parallel(num_sessions=5000):
    """Train V17 agent with self-play on 6-max poker table."""
    agent = DuelingAgent(state_dim=STATE_DIM)
    
    # Dynamic epsilon decay based on num_sessions
    total_batches = num_sessions // SESSIONS_PER_BATCH
    decay_batches = int(total_batches * 0.8)  # Reach min epsilon at 80%
    if decay_batches > 0:
        agent.epsilon_decay = (agent.epsilon_min / agent.epsilon) ** (1.0 / decay_batches)
    
    # Tracking
    all_session_rewards = []
    all_session_profits = []
    loss_history = []
    action_counts_total = {i: 0 for i in range(NUM_ACTIONS)}
    
    # Position tracking
    position_stats = {pos: {'rewards': [], 'wins': 0, 'hands': 0} 
                      for pos in range(6)}
    
    # Session-level tracking (V17 specific)
    session_stats = {
        'completed': 0,
        'busted': 0,
        'self_play_count': 0,
        'scripted_count': 0,
    }
    
    # Risk metrics
    risk_metrics = {
        'allin_count': 0, 'allin_with_weak': 0, 'allin_with_strong': 0,
        'allin_won': 0, 'allin_lost': 0
    }
    
    total_sessions = 0
    batch_count = 0
    total_hands = 0
    start_time = time.time()
    
    # Logging intervals
    log_interval = max(1, int(num_sessions * LOG_PERCENT / 100))
    checkpoint_interval = max(1, int(num_sessions * CHECKPOINT_PERCENT / 100))
    next_log = log_interval
    next_checkpoint = checkpoint_interval
    next_snapshot = SNAPSHOT_INTERVAL
    
    print("="*70)
    print(f"TRAINING V17: SELF-PLAY ({NUM_WORKERS} workers)")
    print("="*70)
    print(f"Total sessions: {num_sessions:,}")
    print(f"Hands per session: {HANDS_PER_SESSION}")
    print(f"Estimated total hands: {num_sessions * HANDS_PER_SESSION:,}")
    print(f"Sessions per batch: {SESSIONS_PER_BATCH}")
    print(f"Total batches: {total_batches:,}")
    print(f"State dimension: {STATE_DIM}")
    print(f"Action space: {NUM_ACTIONS} actions")
    
    print(f"\nEpsilon schedule (dynamic):")
    print(f"  Start: {agent.epsilon:.2f}")
    print(f"  Target: {agent.epsilon_min:.2f} at batch {decay_batches:,} (80% of training)")
    print(f"  Decay factor per batch: {agent.epsilon_decay:.6f}")
    
    print(f"\nV17 Self-Play Config:")
    print(f"  Self-play ratio: {SELF_PLAY_RATIO*100:.0f}%")
    print(f"  Opponent pool size: {OPPONENT_POOL_SIZE}")
    print(f"  Snapshot interval: Every {SNAPSHOT_INTERVAL} sessions")
    
    print(f"\nV17 Penalty Changes (vs V16):")
    print(f"  All-in loss penalty: -10 BB (was -5 BB)")
    print(f"  Bust penalty: -50 BB (was -20 BB)")
    print(f"  All-in frequency threshold: 8% (was 15%)")
    print("="*70)
    
    # Initialize with random model in pool
    agent.save_snapshot_to_pool()
    print(f"\nInitialized opponent pool with random model")
    
    try:
        ctx = mp.get_context('fork')
        print("Using 'fork' context for multiprocessing")
    except:
        ctx = mp.get_context('spawn')
        print("Using 'spawn' context for multiprocessing")
    
    with ProcessPoolExecutor(max_workers=NUM_WORKERS, mp_context=ctx) as executor:
        while total_sessions < num_sessions:
            model_state_dict = agent.get_model_state_dict_cpu()
            opponent_pool = agent.get_opponent_pool_state_dicts()
            
            # Prepare session arguments
            session_args = []
            for i in range(SESSIONS_PER_BATCH):
                seed = random.randint(0, 2**31-1)
                session_args.append((
                    seed, agent.epsilon, EQUITY_ITERATIONS, model_state_dict,
                    HANDS_PER_SESSION, opponent_pool, SELF_PLAY_RATIO
                ))
            
            # Run sessions in parallel
            futures = [executor.submit(run_session_v17, args) for args in session_args]
            
            batch_session_rewards = []
            batch_session_profits = []
            batch_transitions = []
            batch_action_counts = {i: 0 for i in range(NUM_ACTIONS)}
            
            for future in as_completed(futures):
                try:
                    result = future.result()
                    
                    batch_session_rewards.append(result['session_reward'])
                    batch_session_profits.append(result['session_profit_bb'])
                    batch_transitions.extend(result['transitions'])
                    
                    # Track action counts
                    for a, c in result['action_counts'].items():
                        batch_action_counts[a] += c
                        action_counts_total[a] += c
                    
                    # Session stats
                    total_hands += result['hands_completed']
                    if result['session_completed']:
                        session_stats['completed'] += 1
                    if result['busted']:
                        session_stats['busted'] += 1
                    
                    # Track self-play vs scripted
                    if result.get('opponent_mode') == 'self-play':
                        session_stats['self_play_count'] += 1
                    else:
                        session_stats['scripted_count'] += 1
                    
                    # All-in tracking
                    for outcome in result['allin_outcomes']:
                        risk_metrics['allin_count'] += 1
                        strength = compute_hand_strength_category(outcome['equity'])
                        if strength >= 3:
                            risk_metrics['allin_with_strong'] += 1
                        else:
                            risk_metrics['allin_with_weak'] += 1
                        if outcome['won']:
                            risk_metrics['allin_won'] += 1
                        else:
                            risk_metrics['allin_lost'] += 1
                    
                    # Position stats from hand profits
                    for i, pos in enumerate(result['position_history']):
                        if i < len(result['hand_profits']):
                            profit = result['hand_profits'][i]
                            position_stats[pos]['rewards'].append(profit)
                            position_stats[pos]['hands'] += 1
                            if profit > 0:
                                position_stats[pos]['wins'] += 1
                    
                    total_sessions += 1
                except Exception as e:
                    print(f"Session error: {e}")
            
            # Add transitions and train
            agent.add_transitions(batch_transitions)
            
            loss = 0.0
            for _ in range(4):
                loss += agent.train_step()
            loss /= 4
            
            # Decay epsilon once per batch
            agent.decay_epsilon()
            batch_count += 1
            
            # Update target network
            if total_sessions % 100 < SESSIONS_PER_BATCH:
                agent.update_target()
            
            all_session_rewards.extend(batch_session_rewards)
            all_session_profits.extend(batch_session_profits)
            if loss > 0:
                loss_history.append(loss)
            
            # Save snapshot to opponent pool
            if total_sessions >= next_snapshot:
                agent.save_snapshot_to_pool()
                next_snapshot += SNAPSHOT_INTERVAL
            
            # Periodic logging
            if total_sessions >= next_log:
                elapsed = time.time() - start_time
                speed = total_sessions / elapsed
                remaining = (num_sessions - total_sessions) / speed / 60
                
                recent_r = np.mean(batch_session_rewards) if batch_session_rewards else 0
                recent_p = np.mean(batch_session_profits) if batch_session_profits else 0
                
                total_actions = sum(batch_action_counts.values())
                action_pcts = {a: batch_action_counts[a]/total_actions*100 if total_actions > 0 else 0 
                               for a in range(NUM_ACTIONS)}
                
                progress = total_sessions / num_sessions * 100
                survival = (1 - session_stats['busted'] / total_sessions) * 100 if total_sessions > 0 else 100
                
                print(f"Session {total_sessions:,}/{num_sessions:,} ({progress:.1f}%) | Eps={agent.epsilon:.3f} | "
                      f"Avg Reward: {recent_r:+.1f} | Profit: {recent_p:+.1f} BB | Loss: {loss:.4f}")
                print(f"        Survival: {survival:.1f}% | Pool: {len(agent.opponent_pool)} | "
                      f"Hands: {total_hands:,} | Speed: {speed:.1f} s/s | ETA: {remaining:.1f}m")
                print(f"        Actions: Fold {action_pcts[0]:.1f}% | Call {action_pcts[1]:.1f}% | "
                      f"SmR {action_pcts[2]:.1f}% | MedR {action_pcts[3]:.1f}% | LgR {action_pcts[4]:.1f}% | AllIn {action_pcts[5]:.1f}%")
                
                next_log += log_interval
            
            # Checkpoints
            if total_sessions >= next_checkpoint:
                print()
                print("="*70)
                print(f"CHECKPOINT: Session {total_sessions:,} / {num_sessions:,}")
                print("="*70)
                
                # Overall stats
                recent_n = min(500, len(all_session_rewards))
                print(f"\nPerformance (last {recent_n} sessions):")
                print(f"  Avg Session Reward: {np.mean(all_session_rewards[-recent_n:]):+.2f}")
                print(f"  Avg Session Profit: {np.mean(all_session_profits[-recent_n:]):+.2f} BB")
                
                # Session survival
                survival_rate = (1 - session_stats['busted'] / total_sessions) * 100
                print(f"\nSession Stats:")
                print(f"  Completed: {session_stats['completed']:,}")
                print(f"  Busted: {session_stats['busted']:,}")
                print(f"  Survival Rate: {survival_rate:.1f}%")
                print(f"  Self-play sessions: {session_stats['self_play_count']:,}")
                print(f"  Scripted sessions: {session_stats['scripted_count']:,}")
                
                # Position stats
                print(f"\nPosition Performance:")
                for pos in range(6):
                    pstats = position_stats[pos]
                    if pstats['hands'] > 0:
                        avg_bb = np.mean(pstats['rewards']) if pstats['rewards'] else 0
                        win_rate = pstats['wins'] / pstats['hands'] * 100
                        print(f"  {POSITION_NAMES[pos]}: {pstats['hands']:,} hands, "
                              f"Avg: {avg_bb:+.2f} BB, Win: {win_rate:.1f}%")
                
                # Risk analysis
                print(f"\nAll-in Analysis:")
                if risk_metrics['allin_count'] > 0:
                    strong_pct = risk_metrics['allin_with_strong'] / risk_metrics['allin_count'] * 100
                    win_rate = risk_metrics['allin_won'] / risk_metrics['allin_count'] * 100
                    allin_rate = risk_metrics['allin_count'] / total_hands * 100 if total_hands > 0 else 0
                    print(f"  Total all-ins: {risk_metrics['allin_count']} ({allin_rate:.1f}% of hands)")
                    print(f"  With strong hand (60%+ equity): {risk_metrics['allin_with_strong']} ({strong_pct:.1f}%)")
                    print(f"  With weak hand: {risk_metrics['allin_with_weak']} ({100-strong_pct:.1f}%)")
                    print(f"  All-in win rate: {win_rate:.1f}%")
                
                print("="*70)
                print()
                
                next_checkpoint += checkpoint_interval
    
    # Training complete
    total_time = time.time() - start_time
    print("\n" + "="*70)
    print("TRAINING COMPLETE")
    print("="*70)
    print(f"Total sessions: {total_sessions:,}")
    print(f"Total hands: {total_hands:,}")
    print(f"Total time: {total_time/60:.1f} minutes")
    print(f"Speed: {total_sessions/total_time:.1f} sessions/second")
    print(f"Final epsilon: {agent.epsilon:.4f}")
    print(f"Final opponent pool size: {len(agent.opponent_pool)}")
    
    return agent, {
        'session_rewards': all_session_rewards,
        'session_profits': all_session_profits,
        'loss': loss_history,
        'action_counts': action_counts_total,
        'position_stats': position_stats,
        'session_stats': session_stats,
        'risk_metrics': risk_metrics,
    }

# %%
def evaluate_agent_v17(agent, num_sessions=200):
    """Evaluate trained agent on 6-max table."""
    print("\n" + "="*70)
    print("EVALUATION: V17 Self-Play Agent")
    print("="*70)
    
    # Set epsilon to minimum for evaluation
    old_epsilon = agent.epsilon
    agent.epsilon = 0.02
    
    results = []
    position_results = {pos: [] for pos in range(6)}
    action_counts = {i: 0 for i in range(NUM_ACTIONS)}
    risk_metrics = {'allin_count': 0, 'allin_with_weak': 0, 'allin_with_strong': 0,
                    'allin_won': 0, 'allin_lost': 0}
    
    session_stats = {'completed': 0, 'busted': 0}
    total_hands = 0
    
    model_state_dict = agent.get_model_state_dict_cpu()
    # Use scripted opponents for fair evaluation
    opponent_pool = []  # Empty = 100% scripted
    
    try:
        ctx = mp.get_context('fork')
    except:
        ctx = mp.get_context('spawn')
    
    with ProcessPoolExecutor(max_workers=NUM_WORKERS, mp_context=ctx) as executor:
        sessions_done = 0
        while sessions_done < num_sessions:
            batch_size = min(SESSIONS_PER_BATCH, num_sessions - sessions_done)
            
            session_args = []
            for _ in range(batch_size):
                seed = random.randint(0, 2**31-1)
                session_args.append((
                    seed, agent.epsilon, EQUITY_ITERATIONS, model_state_dict,
                    HANDS_PER_SESSION, opponent_pool, 0.0  # 0% self-play for eval
                ))
            
            futures = [executor.submit(run_session_v17, args) for args in session_args]
            
            for future in as_completed(futures):
                try:
                    result = future.result()
                    results.append(result['session_profit_bb'])
                    total_hands += result['hands_completed']
                    
                    if result['session_completed']:
                        session_stats['completed'] += 1
                    if result['busted']:
                        session_stats['busted'] += 1
                    
                    # Position stats
                    for i, pos in enumerate(result['position_history']):
                        if i < len(result['hand_profits']):
                            position_results[pos].append(result['hand_profits'][i])
                    
                    for a, c in result['action_counts'].items():
                        action_counts[a] += c
                    
                    # Risk tracking
                    for outcome in result['allin_outcomes']:
                        risk_metrics['allin_count'] += 1
                        if compute_hand_strength_category(outcome['equity']) >= 3:
                            risk_metrics['allin_with_strong'] += 1
                        else:
                            risk_metrics['allin_with_weak'] += 1
                        if outcome['won']:
                            risk_metrics['allin_won'] += 1
                        else:
                            risk_metrics['allin_lost'] += 1
                    
                    sessions_done += 1
                except Exception as e:
                    print(f"Eval error: {e}")
    
    agent.epsilon = old_epsilon
    
    # Print results
    print(f"\nEvaluated {len(results)} sessions ({total_hands} hands)")
    
    print(f"\nOverall Performance:")
    avg_per_session = np.mean(results)
    avg_per_hand = sum(results) / total_hands if total_hands > 0 else 0
    print(f"  Avg BB/session: {avg_per_session:+.2f}")
    print(f"  Avg BB/hand: {avg_per_hand:+.3f}")
    print(f"  Std dev: {np.std(results):.2f}")
    print(f"  Win rate (sessions): {sum(1 for r in results if r > 0) / len(results) * 100:.1f}%")
    print(f"  Total profit: {sum(results):+.1f} BB")
    
    survival_rate = (1 - session_stats['busted'] / len(results)) * 100
    print(f"\nSession Survival:")
    print(f"  Completed: {session_stats['completed']}")
    print(f"  Busted: {session_stats['busted']}")
    print(f"  Survival Rate: {survival_rate:.1f}%")
    
    print(f"\nPerformance by Position:")
    for pos in range(6):
        pres = position_results[pos]
        if pres:
            avg = np.mean(pres)
            winrate = sum(1 for r in pres if r > 0) / len(pres) * 100
            print(f"  {POSITION_NAMES[pos]}: {len(pres)} hands, Avg: {avg:+.2f} BB, Win: {winrate:.1f}%")
    
    total_actions = sum(action_counts.values())
    print(f"\nAction Distribution:")
    action_names = ['Fold', 'Call', 'SmallRaise', 'MedRaise', 'LargeRaise', 'AllIn']
    for i, name in enumerate(action_names):
        pct = action_counts[i] / total_actions * 100 if total_actions > 0 else 0
        print(f"  {name}: {pct:.1f}%")
    
    print(f"\nRisk Analysis:")
    if risk_metrics['allin_count'] > 0:
        strong_pct = risk_metrics['allin_with_strong'] / risk_metrics['allin_count'] * 100
        win_rate = risk_metrics['allin_won'] / risk_metrics['allin_count'] * 100
        allin_rate = risk_metrics['allin_count'] / total_hands * 100 if total_hands > 0 else 0
        print(f"  All-ins: {risk_metrics['allin_count']} ({allin_rate:.1f}% of hands)")
        print(f"  With strong hand (60%+ equity): {strong_pct:.1f}%")
        print(f"  With weak hand: {100-strong_pct:.1f}%")
        print(f"  All-in win rate: {win_rate:.1f}%")
    else:
        print("  No all-ins during evaluation")
    
    return {
        'results': results,
        'position_results': position_results,
        'action_counts': action_counts,
        'risk_metrics': risk_metrics,
        'session_stats': session_stats,
    }

# %%
# Train the agent
agent, history = train_v17_parallel(num_sessions=5000)
# Out:
# ======================================================================
# TRAINING V17: SELF-PLAY (6 workers)
# ======================================================================
# Total sessions: 5,000
# Hands per session: 30
# Estimated total hands: 150,000
# Sessions per batch: 12
# Total batches: 416
# State dimension: 520
# Action space: 6 actions
#
# Epsilon schedule (dynamic):
#   Start: 1.00
#   Target: 0.05 at batch 332 (80% of training)
#   Decay factor per batch: 0.991017
#
# V17 Self-Play Config:
#   Self-play ratio: 80%
#   Opponent pool size: 15
#   Snapshot interval: Every 500 sessions
#
# V17 Penalty Changes (vs V16):
#   All-in loss penalty: -10 BB (was -5 BB)
#   Bust penalty: -50 BB (was -20 BB)
#   All-in frequency threshold: 8% (was 15%)
# ======================================================================
#
# Initialized opponent pool with random model
# Using 'fork' context for multiprocessing
# /tmp/ipykernel_36563/3034011861.py:49: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   states = torch.FloatTensor([s[0] for s in samples]).to(self.device)
# Session 108/5,000 (2.2%) | Eps=0.922 | Avg Reward: -16.9 | Profit: -5.3 BB | Loss: 206.5685
#         Survival: 58.3% | Pool: 1 | Hands: 2,275 | Speed: 2.8 s/s | ETA: 29.2m
#         Actions: Fold 19.9% | Call 15.0% | SmR 12.5% | MedR 24.4% | LgR 12.2% | AllIn 16.1%
# Session 204/5,000 (4.1%) | Eps=0.858 | Avg Reward: +64.0 | Profit: +73.9 BB | Loss: 255.8579
#         Survival: 63.2% | Pool: 1 | Hands: 4,412 | Speed: 2.8 s/s | ETA: 28.4m
#         Actions: Fold 17.8% | Call 15.6% | SmR 14.5% | MedR 27.3% | LgR 11.5% | AllIn 13.4%
# Session 300/5,000 (6.0%) | Eps=0.798 | Avg Reward: +17.4 | Profit: +34.2 BB | Loss: 192.7775
#         Survival: 64.7% | Pool: 1 | Hands: 6,573 | Speed: 2.8 s/s | ETA: 28.0m
#         Actions: Fold 17.3% | Call 16.3% | SmR 12.5% | MedR 33.6% | LgR 9.8% | AllIn 10.5%
# Session 408/5,000 (8.2%) | Eps=0.736 | Avg Reward: +51.8 | Profit: +71.8 BB | Loss: 267.4192
#         Survival: 65.0% | Pool: 1 | Hands: 9,031 | Speed: 2.8 s/s | ETA: 27.8m
#         Actions: Fold 13.0% | Call 12.7% | SmR 13.9% | MedR 37.5% | LgR 11.5% | AllIn 11.5%
# Session 504/5,000 (10.1%) | Eps=0.685 | Avg Reward: +114.8 | Profit: +119.2 BB | Loss: 165.0313
#         Survival: 64.5% | Pool: 2 | Hands: 11,054 | Speed: 2.7 s/s | ETA: 27.5m
#         Actions: Fold 14.6% | Call 13.3% | SmR 10.3% | MedR 39.0% | LgR 10.5% | AllIn 12.3%
#
# ======================================================================
# CHECKPOINT: Session 504 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: -5.16
#   Avg Session Profit: +17.82 BB
#
# Session Stats:
#   Completed: 327
#   Busted: 179
#   Survival Rate: 64.5%
#   Self-play sessions: 415
#   Scripted sessions: 89
#
# Position Performance:
#   UTG: 1,933 hands, Avg: +0.30 BB, Win: 73.9%
#   MP: 1,890 hands, Avg: -1.04 BB, Win: 85.2%
#   CO: 1,851 hands, Avg: +1.31 BB, Win: 71.2%
#   BTN: 1,823 hands, Avg: +1.25 BB, Win: 73.5%
#   SB: 1,790 hands, Avg: +1.87 BB, Win: 73.3%
#   BB: 1,767 hands, Avg: +1.10 BB, Win: 75.1%
#
# All-in Analysis:
#   Total all-ins: 1864 (16.9% of hands)
#   With strong hand (60%+ equity): 265 (14.2%)
#   With weak hand: 1599 (85.8%)
#   All-in win rate: 85.8%
# ======================================================================
#
# Session 600/5,000 (12.0%) | Eps=0.637 | Avg Reward: +89.2 | Profit: +131.8 BB | Loss: 448.1300
#         Survival: 59.0% | Pool: 2 | Hands: 12,193 | Speed: 2.7 s/s | ETA: 27.5m
#         Actions: Fold 13.5% | Call 16.5% | SmR 9.2% | MedR 42.9% | LgR 8.7% | AllIn 9.2%
# Session 708/5,000 (14.2%) | Eps=0.587 | Avg Reward: +345.2 | Profit: +379.2 BB | Loss: 743.1821
#         Survival: 55.6% | Pool: 2 | Hands: 13,745 | Speed: 2.5 s/s | ETA: 28.3m
#         Actions: Fold 12.9% | Call 18.0% | SmR 9.9% | MedR 40.3% | LgR 8.4% | AllIn 10.5%
# Session 804/5,000 (16.1%) | Eps=0.546 | Avg Reward: +89.1 | Profit: +132.1 BB | Loss: 976.1520
#         Survival: 53.9% | Pool: 2 | Hands: 15,211 | Speed: 2.5 s/s | ETA: 28.4m
#         Actions: Fold 7.2% | Call 17.3% | SmR 50.5% | MedR 6.6% | LgR 8.8% | AllIn 9.6%
# Session 900/5,000 (18.0%) | Eps=0.508 | Avg Reward: +320.0 | Profit: +359.4 BB | Loss: 948.7898
#         Survival: 52.8% | Pool: 2 | Hands: 16,751 | Speed: 2.4 s/s | ETA: 28.4m
#         Actions: Fold 12.8% | Call 18.3% | SmR 48.4% | MedR 5.2% | LgR 7.0% | AllIn 8.4%
# Session 1,008/5,000 (20.2%) | Eps=0.469 | Avg Reward: +311.0 | Profit: +352.6 BB | Loss: 799.7576
#         Survival: 51.8% | Pool: 3 | Hands: 18,398 | Speed: 2.4 s/s | ETA: 27.8m
#         Actions: Fold 7.8% | Call 19.9% | SmR 54.2% | MedR 5.6% | LgR 5.0% | AllIn 7.5%
#
# ======================================================================
# CHECKPOINT: Session 1,008 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: +270.56
#   Avg Session Profit: +306.75 BB
#
# Session Stats:
#   Completed: 525
#   Busted: 486
#   Survival Rate: 51.8%
#   Self-play sessions: 813
#   Scripted sessions: 195
#
# Position Performance:
#   UTG: 3,333 hands, Avg: +10.86 BB, Win: 64.3%
#   MP: 3,181 hands, Avg: +6.97 BB, Win: 70.2%
#   CO: 3,073 hands, Avg: +7.81 BB, Win: 62.1%
#   BTN: 3,000 hands, Avg: +8.82 BB, Win: 64.9%
#   SB: 2,932 hands, Avg: +8.27 BB, Win: 63.8%
#   BB: 2,879 hands, Avg: +9.91 BB, Win: 66.0%
#
# All-in Analysis:
#   Total all-ins: 3585 (19.5% of hands)
#   With strong hand (60%+ equity): 435 (12.1%)
#   With weak hand: 3150 (87.9%)
#   All-in win rate: 85.4%
# ======================================================================
#
# Session 1,104/5,000 (22.1%) | Eps=0.436 | Avg Reward: +39.2 | Profit: +82.4 BB | Loss: 1290.2766
#         Survival: 48.7% | Pool: 3 | Hands: 19,223 | Speed: 2.4 s/s | ETA: 26.7m
#         Actions: Fold 11.9% | Call 22.9% | SmR 48.8% | MedR 5.5% | LgR 6.0% | AllIn 5.0%
# Session 1,200/5,000 (24.0%) | Eps=0.406 | Avg Reward: +163.9 | Profit: +206.7 BB | Loss: 1492.1357
#         Survival: 46.1% | Pool: 3 | Hands: 20,082 | Speed: 2.5 s/s | ETA: 25.8m
#         Actions: Fold 12.2% | Call 34.0% | SmR 43.6% | MedR 3.7% | LgR 4.8% | AllIn 1.6%
# Session 1,308/5,000 (26.2%) | Eps=0.374 | Avg Reward: +73.5 | Profit: +121.6 BB | Loss: 1642.4868
#         Survival: 43.7% | Pool: 3 | Hands: 20,865 | Speed: 2.5 s/s | ETA: 24.8m
#         Actions: Fold 6.0% | Call 26.0% | SmR 54.7% | MedR 3.8% | LgR 4.5% | AllIn 4.9%
# Session 1,404/5,000 (28.1%) | Eps=0.348 | Avg Reward: -26.6 | Profit: +21.3 BB | Loss: 841.9155
#         Survival: 41.5% | Pool: 3 | Hands: 21,526 | Speed: 2.5 s/s | ETA: 23.9m
#         Actions: Fold 8.4% | Call 22.7% | SmR 59.7% | MedR 3.4% | LgR 1.7% | AllIn 4.2%
# Session 1,500/5,000 (30.0%) | Eps=0.324 | Avg Reward: +105.4 | Profit: +146.3 BB | Loss: 1374.1136
#         Survival: 39.6% | Pool: 4 | Hands: 22,153 | Speed: 2.5 s/s | ETA: 23.1m
#         Actions: Fold 5.4% | Call 15.6% | SmR 7.6% | MedR 63.8% | LgR 5.6% | AllIn 2.0%
#
# ======================================================================
# CHECKPOINT: Session 1,500 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: +31.40
#   Avg Session Profit: +78.33 BB
#
# Session Stats:
#   Completed: 597
#   Busted: 906
#   Survival Rate: 39.6%
#   Self-play sessions: 1,187
#   Scripted sessions: 313
#
# Position Performance:
#   UTG: 4,236 hands, Avg: +10.25 BB, Win: 58.6%
#   MP: 3,859 hands, Avg: +6.26 BB, Win: 64.2%
#   CO: 3,670 hands, Avg: +8.52 BB, Win: 58.1%
#   BTN: 3,550 hands, Avg: +10.13 BB, Win: 60.9%
#   SB: 3,458 hands, Avg: +8.38 BB, Win: 59.5%
#   BB: 3,380 hands, Avg: +9.55 BB, Win: 61.6%
#
# All-in Analysis:
#   Total all-ins: 4064 (18.3% of hands)
#   With strong hand (60%+ equity): 482 (11.9%)
#   With weak hand: 3582 (88.1%)
#   All-in win rate: 81.4%
# ======================================================================
#
# Session 1,608/5,000 (32.2%) | Eps=0.298 | Avg Reward: -151.7 | Profit: -100.0 BB | Loss: 1816.7527
#         Survival: 37.7% | Pool: 4 | Hands: 23,019 | Speed: 2.6 s/s | ETA: 22.2m
#         Actions: Fold 8.9% | Call 25.8% | SmR 58.1% | MedR 2.4% | LgR 3.2% | AllIn 1.6%
# Session 1,704/5,000 (34.1%) | Eps=0.278 | Avg Reward: +23.5 | Profit: +66.4 BB | Loss: 2090.4796
#         Survival: 36.4% | Pool: 4 | Hands: 23,720 | Speed: 2.6 s/s | ETA: 21.5m
#         Actions: Fold 11.2% | Call 27.7% | SmR 51.8% | MedR 3.6% | LgR 3.6% | AllIn 2.2%
# Session 1,800/5,000 (36.0%) | Eps=0.258 | Avg Reward: +29.3 | Profit: +69.6 BB | Loss: 2634.6738
#         Survival: 35.3% | Pool: 4 | Hands: 24,532 | Speed: 2.6 s/s | ETA: 20.9m
#         Actions: Fold 4.2% | Call 26.1% | SmR 61.3% | MedR 3.1% | LgR 2.4% | AllIn 2.8%
# Session 1,908/5,000 (38.2%) | Eps=0.238 | Avg Reward: -134.5 | Profit: -86.8 BB | Loss: 1652.6689
#         Survival: 34.3% | Pool: 4 | Hands: 25,359 | Speed: 2.5 s/s | ETA: 20.3m
#         Actions: Fold 2.1% | Call 8.4% | SmR 3.7% | MedR 4.2% | LgR 79.1% | AllIn 2.6%
# Session 2,004/5,000 (40.1%) | Eps=0.222 | Avg Reward: +175.2 | Profit: +217.2 BB | Loss: 2379.9329
#         Survival: 33.4% | Pool: 5 | Hands: 26,084 | Speed: 2.5 s/s | ETA: 19.7m
#         Actions: Fold 5.1% | Call 28.0% | SmR 3.4% | MedR 2.9% | LgR 58.9% | AllIn 1.7%
#
# ======================================================================
# CHECKPOINT: Session 2,004 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: +41.12
#   Avg Session Profit: +86.58 BB
#
# Session Stats:
#   Completed: 674
#   Busted: 1,335
#   Survival Rate: 33.4%
#   Self-play sessions: 1,600
#   Scripted sessions: 404
#
# Position Performance:
#   UTG: 5,182 hands, Avg: +10.92 BB, Win: 54.4%
#   MP: 4,540 hands, Avg: +7.40 BB, Win: 60.1%
#   CO: 4,285 hands, Avg: +8.19 BB, Win: 54.6%
#   BTN: 4,140 hands, Avg: +9.60 BB, Win: 56.9%
#   SB: 4,021 hands, Avg: +8.89 BB, Win: 56.3%
#   BB: 3,916 hands, Avg: +9.77 BB, Win: 57.7%
#
# All-in Analysis:
#   Total all-ins: 4402 (16.9% of hands)
#   With strong hand (60%+ equity): 520 (11.8%)
#   With weak hand: 3882 (88.2%)
#   All-in win rate: 78.9%
# ======================================================================
#
# Session 2,100/5,000 (42.0%) | Eps=0.206 | Avg Reward: +98.1 | Profit: +152.2 BB | Loss: 2851.5863
#         Survival: 32.4% | Pool: 5 | Hands: 26,701 | Speed: 2.5 s/s | ETA: 19.1m
#         Actions: Fold 4.4% | Call 16.1% | SmR 2.3% | MedR 68.5% | LgR 3.4% | AllIn 5.4%
# Session 2,208/5,000 (44.2%) | Eps=0.190 | Avg Reward: -7.5 | Profit: +43.1 BB | Loss: 2513.7363
#         Survival: 31.5% | Pool: 5 | Hands: 27,500 | Speed: 2.5 s/s | ETA: 18.5m
#         Actions: Fold 1.9% | Call 17.5% | SmR 32.7% | MedR 41.2% | LgR 3.3% | AllIn 3.3%
# Session 2,304/5,000 (46.1%) | Eps=0.177 | Avg Reward: -53.7 | Profit: -5.6 BB | Loss: 3103.7790
#         Survival: 30.5% | Pool: 5 | Hands: 28,000 | Speed: 2.5 s/s | ETA: 17.7m
#         Actions: Fold 3.3% | Call 19.4% | SmR 1.7% | MedR 70.2% | LgR 3.3% | AllIn 2.1%
# Session 2,400/5,000 (48.0%) | Eps=0.165 | Avg Reward: -152.2 | Profit: -100.0 BB | Loss: 2402.4401
#         Survival: 29.8% | Pool: 5 | Hands: 28,624 | Speed: 2.5 s/s | ETA: 17.1m
#         Actions: Fold 3.3% | Call 7.9% | SmR 1.9% | MedR 79.4% | LgR 5.6% | AllIn 1.9%
# Session 2,508/5,000 (50.2%) | Eps=0.152 | Avg Reward: -151.8 | Profit: -99.8 BB | Loss: 2621.0253
#         Survival: 28.9% | Pool: 6 | Hands: 29,247 | Speed: 2.5 s/s | ETA: 16.3m
#         Actions: Fold 1.4% | Call 11.0% | SmR 1.4% | MedR 80.7% | LgR 1.4% | AllIn 4.1%
#
# ======================================================================
# CHECKPOINT: Session 2,508 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: -0.35
#   Avg Session Profit: +46.12 BB
#
# Session Stats:
#   Completed: 730
#   Busted: 1,783
#   Survival Rate: 28.9%
#   Self-play sessions: 2,006
#   Scripted sessions: 502
#
# Position Performance:
#   UTG: 6,028 hands, Avg: +9.30 BB, Win: 50.6%
#   MP: 5,067 hands, Avg: +7.67 BB, Win: 57.5%
#   CO: 4,766 hands, Avg: +9.19 BB, Win: 52.8%
#   BTN: 4,602 hands, Avg: +8.94 BB, Win: 54.1%
#   SB: 4,456 hands, Avg: +8.84 BB, Win: 53.7%
#   BB: 4,328 hands, Avg: +9.79 BB, Win: 55.2%
#
# All-in Analysis:
#   Total all-ins: 4601 (15.7% of hands)
#   With strong hand (60%+ equity): 542 (11.8%)
#   With weak hand: 4059 (88.2%)
#   All-in win rate: 77.2%
# ======================================================================
#
# Session 2,604/5,000 (52.1%) | Eps=0.141 | Avg Reward: +14.7 | Profit: +63.6 BB | Loss: 3969.0576
#         Survival: 28.2% | Pool: 6 | Hands: 29,868 | Speed: 2.5 s/s | ETA: 15.7m
#         Actions: Fold 4.7% | Call 35.5% | SmR 2.8% | MedR 53.3% | LgR 0.0% | AllIn 3.7%
# Session 2,700/5,000 (54.0%) | Eps=0.131 | Avg Reward: -151.7 | Profit: -100.0 BB | Loss: 2883.6564
#         Survival: 27.5% | Pool: 6 | Hands: 30,378 | Speed: 2.6 s/s | ETA: 15.0m
#         Actions: Fold 2.9% | Call 19.9% | SmR 1.0% | MedR 73.3% | LgR 1.9% | AllIn 1.0%
# Session 2,808/5,000 (56.2%) | Eps=0.121 | Avg Reward: -150.7 | Profit: -99.8 BB | Loss: 3094.9343
#         Survival: 26.8% | Pool: 6 | Hands: 30,964 | Speed: 2.6 s/s | ETA: 14.3m
#         Actions: Fold 2.9% | Call 18.3% | SmR 3.8% | MedR 74.0% | LgR 0.0% | AllIn 1.0%
# Session 2,904/5,000 (58.1%) | Eps=0.113 | Avg Reward: -82.9 | Profit: -34.9 BB | Loss: 1827.9356
#         Survival: 26.3% | Pool: 6 | Hands: 31,598 | Speed: 2.6 s/s | ETA: 13.7m
#         Actions: Fold 2.6% | Call 17.7% | SmR 32.3% | MedR 44.0% | LgR 1.9% | AllIn 1.4%
# Session 3,000/5,000 (60.0%) | Eps=0.105 | Avg Reward: -48.8 | Profit: -1.2 BB | Loss: 3478.1336
#         Survival: 25.6% | Pool: 7 | Hands: 32,064 | Speed: 2.6 s/s | ETA: 13.0m
#         Actions: Fold 1.8% | Call 16.7% | SmR 11.0% | MedR 59.6% | LgR 8.8% | AllIn 2.2%
#
# ======================================================================
# CHECKPOINT: Session 3,000 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: -43.76
#   Avg Session Profit: +3.30 BB
#
# Session Stats:
#   Completed: 775
#   Busted: 2,231
#   Survival Rate: 25.6%
#   Self-play sessions: 2,400
#   Scripted sessions: 600
#
# Position Performance:
#   UTG: 6,815 hands, Avg: +7.76 BB, Win: 48.2%
#   MP: 5,535 hands, Avg: +6.71 BB, Win: 55.2%
#   CO: 5,195 hands, Avg: +9.13 BB, Win: 51.1%
#   BTN: 5,001 hands, Avg: +8.00 BB, Win: 51.9%
#   SB: 4,833 hands, Avg: +9.02 BB, Win: 52.1%
#   BB: 4,685 hands, Avg: +9.19 BB, Win: 53.3%
#
# All-in Analysis:
#   Total all-ins: 4744 (14.8% of hands)
#   With strong hand (60%+ equity): 554 (11.7%)
#   With weak hand: 4190 (88.3%)
#   All-in win rate: 76.1%
# ======================================================================
#
# Session 3,108/5,000 (62.2%) | Eps=0.097 | Avg Reward: +30.6 | Profit: +72.6 BB | Loss: 2802.5725
#         Survival: 25.0% | Pool: 7 | Hands: 32,676 | Speed: 2.6 s/s | ETA: 12.3m
#         Actions: Fold 2.1% | Call 26.1% | SmR 1.0% | MedR 58.4% | LgR 11.7% | AllIn 0.7%
# Session 3,204/5,000 (64.1%) | Eps=0.090 | Avg Reward: +173.3 | Profit: +215.3 BB | Loss: 2383.7795
#         Survival: 24.6% | Pool: 7 | Hands: 33,241 | Speed: 2.6 s/s | ETA: 11.7m
#         Actions: Fold 2.1% | Call 31.8% | SmR 1.2% | MedR 63.2% | LgR 0.8% | AllIn 0.8%
# Session 3,300/5,000 (66.0%) | Eps=0.084 | Avg Reward: +40.6 | Profit: +83.5 BB | Loss: 3977.1632
#         Survival: 24.2% | Pool: 7 | Hands: 33,858 | Speed: 2.6 s/s | ETA: 11.1m
#         Actions: Fold 2.9% | Call 20.9% | SmR 2.0% | MedR 60.6% | LgR 12.5% | AllIn 1.2%
# Session 3,408/5,000 (68.2%) | Eps=0.077 | Avg Reward: +53.6 | Profit: +95.9 BB | Loss: 3505.5253
#         Survival: 23.5% | Pool: 7 | Hands: 34,296 | Speed: 2.6 s/s | ETA: 10.3m
#         Actions: Fold 2.0% | Call 26.6% | SmR 1.2% | MedR 56.6% | LgR 12.5% | AllIn 1.2%
# Session 3,504/5,000 (70.1%) | Eps=0.072 | Avg Reward: -150.0 | Profit: -100.0 BB | Loss: 3988.4094
#         Survival: 23.0% | Pool: 8 | Hands: 34,698 | Speed: 2.6 s/s | ETA: 9.7m
#         Actions: Fold 3.9% | Call 18.2% | SmR 0.0% | MedR 45.5% | LgR 31.2% | AllIn 1.3%
#
# ======================================================================
# CHECKPOINT: Session 3,504 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: -43.47
#   Avg Session Profit: +3.58 BB
#
# Session Stats:
#   Completed: 812
#   Busted: 2,698
#   Survival Rate: 23.0%
#   Self-play sessions: 2,805
#   Scripted sessions: 699
#
# Position Performance:
#   UTG: 7,584 hands, Avg: +6.85 BB, Win: 46.0%
#   MP: 5,967 hands, Avg: +5.96 BB, Win: 53.3%
#   CO: 5,584 hands, Avg: +9.48 BB, Win: 49.9%
#   BTN: 5,366 hands, Avg: +6.92 BB, Win: 50.2%
#   SB: 5,183 hands, Avg: +9.31 BB, Win: 50.6%
#   BB: 5,014 hands, Avg: +7.92 BB, Win: 51.6%
#
# All-in Analysis:
#   Total all-ins: 4823 (13.9% of hands)
#   With strong hand (60%+ equity): 563 (11.7%)
#   With weak hand: 4260 (88.3%)
#   All-in win rate: 75.4%
# ======================================================================
#
# Session 3,600/5,000 (72.0%) | Eps=0.067 | Avg Reward: -107.1 | Profit: -60.7 BB | Loss: 3278.7378
#         Survival: 22.5% | Pool: 8 | Hands: 35,116 | Speed: 2.6 s/s | ETA: 9.0m
#         Actions: Fold 0.7% | Call 12.5% | SmR 1.1% | MedR 42.5% | LgR 42.9% | AllIn 0.4%
# Session 3,708/5,000 (74.2%) | Eps=0.062 | Avg Reward: +17.3 | Profit: +63.7 BB | Loss: 4639.1360
#         Survival: 22.1% | Pool: 8 | Hands: 35,824 | Speed: 2.6 s/s | ETA: 8.4m
#         Actions: Fold 0.6% | Call 24.0% | SmR 0.0% | MedR 45.8% | LgR 29.1% | AllIn 0.6%
# Session 3,804/5,000 (76.1%) | Eps=0.057 | Avg Reward: -73.6 | Profit: -27.2 BB | Loss: 4022.2374
#         Survival: 21.8% | Pool: 8 | Hands: 36,400 | Speed: 2.6 s/s | ETA: 7.8m
#         Actions: Fold 1.4% | Call 27.4% | SmR 0.9% | MedR 66.5% | LgR 3.3% | AllIn 0.5%
# Session 3,900/5,000 (78.0%) | Eps=0.053 | Avg Reward: -59.1 | Profit: -11.9 BB | Loss: 4357.0946
#         Survival: 21.5% | Pool: 8 | Hands: 37,030 | Speed: 2.6 s/s | ETA: 7.2m
#         Actions: Fold 1.7% | Call 35.1% | SmR 2.5% | MedR 59.8% | LgR 0.0% | AllIn 0.8%
# Session 4,008/5,000 (80.2%) | Eps=0.050 | Avg Reward: -149.8 | Profit: -99.8 BB | Loss: 3202.1132
#         Survival: 21.0% | Pool: 9 | Hands: 37,429 | Speed: 2.6 s/s | ETA: 6.4m
#         Actions: Fold 1.7% | Call 28.2% | SmR 56.4% | MedR 6.0% | LgR 7.7% | AllIn 0.0%
#
# ======================================================================
# CHECKPOINT: Session 4,008 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: -47.56
#   Avg Session Profit: -0.51 BB
#
# Session Stats:
#   Completed: 849
#   Busted: 3,166
#   Survival Rate: 21.0%
#   Self-play sessions: 3,210
#   Scripted sessions: 798
#
# Position Performance:
#   UTG: 8,363 hands, Avg: +6.77 BB, Win: 44.4%
#   MP: 6,419 hands, Avg: +5.77 BB, Win: 51.7%
#   CO: 5,993 hands, Avg: +8.48 BB, Win: 48.5%
#   BTN: 5,757 hands, Avg: +6.51 BB, Win: 48.8%
#   SB: 5,546 hands, Avg: +7.54 BB, Win: 48.9%
#   BB: 5,351 hands, Avg: +7.68 BB, Win: 50.2%
#
# All-in Analysis:
#   Total all-ins: 4886 (13.1% of hands)
#   With strong hand (60%+ equity): 567 (11.6%)
#   With weak hand: 4319 (88.4%)
#   All-in win rate: 74.8%
# ======================================================================
#
# Session 4,104/5,000 (82.1%) | Eps=0.050 | Avg Reward: -28.3 | Profit: +18.1 BB | Loss: 5281.1039
#         Survival: 20.7% | Pool: 9 | Hands: 37,891 | Speed: 2.6 s/s | ETA: 5.8m
#         Actions: Fold 0.0% | Call 37.3% | SmR 55.9% | MedR 0.0% | LgR 5.9% | AllIn 1.0%
# Session 4,200/5,000 (84.0%) | Eps=0.050 | Avg Reward: +25.4 | Profit: +70.9 BB | Loss: 4058.2676
#         Survival: 20.5% | Pool: 9 | Hands: 38,453 | Speed: 2.6 s/s | ETA: 5.2m
#         Actions: Fold 2.0% | Call 15.3% | SmR 53.8% | MedR 0.7% | LgR 28.2% | AllIn 0.0%
# Session 4,308/5,000 (86.2%) | Eps=0.050 | Avg Reward: -150.2 | Profit: -100.0 BB | Loss: 4316.9192
#         Survival: 20.1% | Pool: 9 | Hands: 39,045 | Speed: 2.6 s/s | ETA: 4.5m
#         Actions: Fold 2.2% | Call 13.7% | SmR 54.6% | MedR 0.0% | LgR 29.0% | AllIn 0.5%
# Session 4,404/5,000 (88.1%) | Eps=0.050 | Avg Reward: +340.7 | Profit: +370.3 BB | Loss: 5887.6800
#         Survival: 19.9% | Pool: 9 | Hands: 39,601 | Speed: 2.6 s/s | ETA: 3.8m
#         Actions: Fold 0.9% | Call 39.7% | SmR 56.9% | MedR 0.3% | LgR 1.5% | AllIn 0.6%
# Session 4,500/5,000 (90.0%) | Eps=0.050 | Avg Reward: +127.6 | Profit: +170.7 BB | Loss: 4436.5708
#         Survival: 19.7% | Pool: 10 | Hands: 40,170 | Speed: 2.6 s/s | ETA: 3.2m
#         Actions: Fold 1.0% | Call 25.7% | SmR 56.0% | MedR 0.5% | LgR 15.2% | AllIn 1.6%
#
# ======================================================================
# CHECKPOINT: Session 4,500 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: -25.69
#   Avg Session Profit: +20.16 BB
#
# Session Stats:
#   Completed: 894
#   Busted: 3,613
#   Survival Rate: 19.7%
#   Self-play sessions: 3,611
#   Scripted sessions: 889
#
# Position Performance:
#   UTG: 9,139 hands, Avg: +6.09 BB, Win: 43.1%
#   MP: 6,856 hands, Avg: +6.45 BB, Win: 50.7%
#   CO: 6,402 hands, Avg: +7.61 BB, Win: 47.3%
#   BTN: 6,149 hands, Avg: +6.19 BB, Win: 47.7%
#   SB: 5,920 hands, Avg: +7.63 BB, Win: 47.7%
#   BB: 5,704 hands, Avg: +7.72 BB, Win: 48.9%
#
# All-in Analysis:
#   Total all-ins: 4929 (12.3% of hands)
#   With strong hand (60%+ equity): 573 (11.6%)
#   With weak hand: 4356 (88.4%)
#   All-in win rate: 74.4%
# ======================================================================
#
# Session 4,608/5,000 (92.2%) | Eps=0.050 | Avg Reward: +27.4 | Profit: +73.0 BB | Loss: 3735.2727
#         Survival: 19.4% | Pool: 10 | Hands: 40,715 | Speed: 2.6 s/s | ETA: 2.5m
#         Actions: Fold 2.2% | Call 36.6% | SmR 53.8% | MedR 0.0% | LgR 7.5% | AllIn 0.0%
# Session 4,704/5,000 (94.1%) | Eps=0.050 | Avg Reward: +72.9 | Profit: +119.3 BB | Loss: 5121.6558
#         Survival: 19.1% | Pool: 10 | Hands: 41,108 | Speed: 2.6 s/s | ETA: 1.9m
#         Actions: Fold 4.0% | Call 21.1% | SmR 29.1% | MedR 0.0% | LgR 45.2% | AllIn 0.5%
# Session 4,800/5,000 (96.0%) | Eps=0.050 | Avg Reward: +142.5 | Profit: +189.0 BB | Loss: 4132.2872
#         Survival: 18.9% | Pool: 10 | Hands: 41,635 | Speed: 2.6 s/s | ETA: 1.3m
#         Actions: Fold 2.2% | Call 30.9% | SmR 54.7% | MedR 0.0% | LgR 11.5% | AllIn 0.7%
# Session 4,908/5,000 (98.2%) | Eps=0.050 | Avg Reward: -150.8 | Profit: -100.0 BB | Loss: 3509.2271
#         Survival: 18.6% | Pool: 10 | Hands: 42,195 | Speed: 2.6 s/s | ETA: 0.6m
#         Actions: Fold 2.7% | Call 14.5% | SmR 16.4% | MedR 0.0% | LgR 65.5% | AllIn 0.9%
# Session 5,004/5,000 (100.1%) | Eps=0.050 | Avg Reward: +105.6 | Profit: +147.6 BB | Loss: 3508.0981
#         Survival: 18.5% | Pool: 11 | Hands: 42,756 | Speed: 2.6 s/s | ETA: -0.0m
#         Actions: Fold 1.3% | Call 25.1% | SmR 44.6% | MedR 0.4% | LgR 27.7% | AllIn 0.9%
#
# ======================================================================
# CHECKPOINT: Session 5,004 / 5,000
# ======================================================================
#
# Performance (last 500 sessions):
#   Avg Session Reward: -37.12
#   Avg Session Profit: +9.58 BB
#
# Session Stats:
#   Completed: 933
#   Busted: 4,079
#   Survival Rate: 18.5%
#   Self-play sessions: 4,013
#   Scripted sessions: 991
#
# Position Performance:
#   UTG: 9,900 hands, Avg: +5.63 BB, Win: 42.1%
#   MP: 7,269 hands, Avg: +6.68 BB, Win: 49.7%
#   CO: 6,794 hands, Avg: +7.29 BB, Win: 46.4%
#   BTN: 6,511 hands, Avg: +5.95 BB, Win: 46.5%
#   SB: 6,258 hands, Avg: +7.16 BB, Win: 46.7%
#   BB: 6,024 hands, Avg: +7.09 BB, Win: 47.8%
#
# All-in Analysis:
#   Total all-ins: 4978 (11.6% of hands)
#   With strong hand (60%+ equity): 579 (11.6%)
#   With weak hand: 4399 (88.4%)
#   All-in win rate: 73.9%
# ======================================================================
#
#
# ======================================================================
# TRAINING COMPLETE
# ======================================================================
# Total sessions: 5,004
# Total hands: 42,756
# Total time: 32.3 minutes
# Speed: 2.6 sessions/second
# Final epsilon: 0.0500
# Final opponent pool size: 11

# %%
# Evaluate the agent
eval_results = evaluate_agent_v17(agent, num_sessions=200)
# Out:
# ======================================================================
# EVALUATION: V17 Self-Play Agent
# ======================================================================
#
# Evaluated 200 sessions (1457 hands)
#
# Overall Performance:
#   Avg BB/session: -91.41
#   Avg BB/hand: -12.548
#   Std dev: 52.56
#   Win rate (sessions): 2.5%
#   Total profit: -18282.5 BB
#
# Session Survival:
#   Completed: 8
#   Busted: 192
#   Survival Rate: 4.0%
#
# Performance by Position:
#   UTG: 341 hands, Avg: -11.70 BB, Win: 51.9%
#   MP: 276 hands, Avg: -13.31 BB, Win: 46.4%
#   CO: 249 hands, Avg: -11.07 BB, Win: 48.6%
#   BTN: 221 hands, Avg: -18.42 BB, Win: 48.4%
#   SB: 197 hands, Avg: -10.63 BB, Win: 42.6%
#   BB: 173 hands, Avg: -9.81 BB, Win: 46.2%
#
# Action Distribution:
#   Fold: 1.7%
#   Call: 3.3%
#   SmallRaise: 22.1%
#   MedRaise: 0.6%
#   LargeRaise: 72.2%
#   AllIn: 0.2%
#
# Risk Analysis:
#   All-ins: 14 (1.0% of hands)
#   With strong hand (60%+ equity): 21.4%
#   With weak hand: 78.6%
#   All-in win rate: 50.0%

# %%
# Plot training curves
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Session rewards
ax1 = axes[0, 0]
window = 100
if len(history['session_rewards']) >= window:
    smoothed = np.convolve(history['session_rewards'], 
                           np.ones(window)/window, mode='valid')
    ax1.plot(smoothed, alpha=0.8)
ax1.axhline(y=0, color='r', linestyle='--', alpha=0.5)
ax1.set_xlabel('Session')
ax1.set_ylabel('Session Reward')
ax1.set_title('Session Rewards (Smoothed)')
ax1.grid(True, alpha=0.3)

# Session profits
ax2 = axes[0, 1]
if len(history['session_profits']) >= window:
    smoothed = np.convolve(history['session_profits'], 
                           np.ones(window)/window, mode='valid')
    ax2.plot(smoothed, alpha=0.8, color='green')
ax2.axhline(y=0, color='r', linestyle='--', alpha=0.5)
ax2.set_xlabel('Session')
ax2.set_ylabel('Session Profit (BB)')
ax2.set_title('Session Profits (Smoothed)')
ax2.grid(True, alpha=0.3)

# Loss
ax3 = axes[1, 0]
if history['loss']:
    loss_window = min(100, len(history['loss']))
    if len(history['loss']) >= loss_window:
        smoothed_loss = np.convolve(history['loss'], 
                                    np.ones(loss_window)/loss_window, mode='valid')
        ax3.plot(smoothed_loss)
        ax3.set_xlabel('Training Step')
        ax3.set_ylabel('Loss')
        ax3.set_title('Training Loss (Smoothed)')
        ax3.set_yscale('log')
        ax3.grid(True, alpha=0.3)

# Action distribution
ax4 = axes[1, 1]
action_names = ['Fold', 'Call', 'SmR', 'MedR', 'LgR', 'AllIn']
total = sum(history['action_counts'].values())
if total > 0:
    pcts = [history['action_counts'][i]/total*100 for i in range(6)]
    colors = ['#e74c3c', '#3498db', '#2ecc71', '#f1c40f', '#9b59b6', '#e67e22']
    ax4.bar(action_names, pcts, color=colors)
    ax4.set_ylabel('Percentage')
    ax4.set_title('Action Distribution')
    ax4.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('v17_training_curves.png', dpi=150)
plt.show()

# %%
# Save the model
torch.save({
    'model_state_dict': agent.policy_net.state_dict(),
    'optimizer_state_dict': agent.optimizer.state_dict(),
    'epsilon': agent.epsilon,
    'opponent_pool': agent.opponent_pool,
    'history': history,
}, 'poker_agent_v17.pt')
print("Model saved to poker_agent_v17.pt")
# Out:
# Model saved to poker_agent_v17.pt
